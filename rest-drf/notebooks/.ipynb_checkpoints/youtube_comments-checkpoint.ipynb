# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
driver = webdriver.Firefox()
link = 'https://www.youtube.com/watch?v=K1bEFgIYuCI'
driver.get(link)
time.sleep(1.5)
driver.execute_script("window.scrollTo(0, 1000)")
time.sleep(0.5)
driver.execute_script("window.scrollTo(0, 500)")
time.sleep(1.5)
driver.execute_script("window.scrollTo(0, 2500)")
time.sleep(1)
comments = driver.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer')
soup = BeautifulSoup(comments.get_attribute('innerHTML'), 'html.parser')

# %%
comments = driver.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer')
soup = BeautifulSoup(comments.get_attribute('innerHTML'), 'html.parser')
print(soup.prettify())
# Out:
# <!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header">
#  <ytd-comments-header-renderer class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <div class="style-scope ytd-comments-header-renderer" id="title">
#    <h2 class="style-scope ytd-comments-header-renderer" id="count">
#     <yt-formatted-string class="count-text style-scope ytd-comments-header-renderer">
#      6,064 Comments
#     </yt-formatted-string>
#    </h2>
#    <span class="style-scope ytd-comments-header-renderer" id="sort-menu">
#     <yt-sort-filter-sub-menu-renderer class="style-scope ytd-comments-header-renderer">
#      <!--css-build:shady-->
#      <paper-tooltip class="style-scope yt-sort-filter-sub-menu-renderer" role="tooltip" tabindex="-1">
#       <!--css-build:shady-->
#       <div class="hidden style-scope paper-tooltip" id="tooltip">
#        Sort comments
#       </div>
#      </paper-tooltip>
#      <yt-dropdown-menu class="style-scope yt-sort-filter-sub-menu-renderer has-items">
#       <!--css-build:shady-->
#       <paper-menu-button aria-disabled="false" aria-haspopup="true" class="style-scope yt-dropdown-menu" dynamic-align="" horizontal-align="left" role="group" vertical-align="top">
#        <!--css-build:shady-->
#        <div class="style-scope paper-menu-button" id="trigger">
#         <paper-button animated="" aria-disabled="false" aria-expanded="false" aria-label="Sort comments" class="dropdown-trigger style-scope yt-dropdown-menu" elevation="0" id="label" role="button" slot="dropdown-trigger" tabindex="0">
#          <!--css-build:shady-->
#          <yt-icon class="style-scope yt-dropdown-menu" id="label-icon">
#           <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#            <g class="style-scope yt-icon">
#             <path class="style-scope yt-icon" d="M3 18h6v-2H3v2zM3 6v2h18V6H3zm0 7h12v-2H3v2z">
#             </path>
#             <path class="style-scope yt-icon" d="M0 0h24v24H0z" fill="none">
#             </path>
#            </g>
#           </svg>
#           <!--css-build:shady-->
#          </yt-icon>
#          <div class="style-scope yt-dropdown-menu" id="icon-label">
#           Sort by
#          </div>
#          <dom-if class="style-scope yt-dropdown-menu">
#           <template is="dom-if">
#           </template>
#          </dom-if>
#          <dom-if class="style-scope yt-dropdown-menu">
#           <template is="dom-if">
#           </template>
#          </dom-if>
#         </paper-button>
#        </div>
#        <iron-dropdown aria-disabled="false" aria-hidden="true" class="style-scope paper-menu-button" horizontal-align="left" id="dropdown" style="outline: currentcolor none medium; display: none;" vertical-align="top">
#         <!--css-build:shady-->
#         <div class="style-scope iron-dropdown" id="contentWrapper">
#          <div class="dropdown-content style-scope paper-menu-button" slot="dropdown-content">
#           <paper-listbox class="dropdown-content style-scope yt-dropdown-menu" id="menu" role="listbox" slot="dropdown-content" tabindex="0">
#            <!--css-build:shady-->
#            <a aria-selected="true" class="yt-simple-endpoint style-scope yt-dropdown-menu iron-selected" tabindex="0">
#             <paper-item aria-disabled="false" class="style-scope yt-dropdown-menu" role="option" tabindex="0">
#              <!--css-build:shady-->
#              <paper-item-body class="style-scope yt-dropdown-menu">
#               <!--css-build:shady-->
#               <div class="item style-scope yt-dropdown-menu">
#                Top comments
#               </div>
#               <div class="style-scope yt-dropdown-menu" hidden="" id="subtitle" secondary="">
#               </div>
#              </paper-item-body>
#              <yt-reload-continuation class="style-scope yt-dropdown-menu">
#              </yt-reload-continuation>
#             </paper-item>
#            </a>
#            <a aria-selected="false" class="yt-simple-endpoint style-scope yt-dropdown-menu" tabindex="-1">
#             <paper-item aria-disabled="false" class="style-scope yt-dropdown-menu" role="option" tabindex="0">
#              <!--css-build:shady-->
#              <paper-item-body class="style-scope yt-dropdown-menu">
#               <!--css-build:shady-->
#               <div class="item style-scope yt-dropdown-menu">
#                Newest first
#               </div>
#               <div class="style-scope yt-dropdown-menu" hidden="" id="subtitle" secondary="">
#               </div>
#              </paper-item-body>
#              <yt-reload-continuation class="style-scope yt-dropdown-menu">
#              </yt-reload-continuation>
#             </paper-item>
#            </a>
#            <dom-repeat class="style-scope yt-dropdown-menu" id="repeat">
#             <template is="dom-repeat">
#             </template>
#            </dom-repeat>
#           </paper-listbox>
#          </div>
#         </div>
#        </iron-dropdown>
#       </paper-menu-button>
#      </yt-dropdown-menu>
#     </yt-sort-filter-sub-menu-renderer>
#    </span>
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" hidden="" id="red-commenting-div">
#    <yt-formatted-string class="style-scope ytd-comments-header-renderer" id="red-commenting-text">
#     <!--css-build:shady-->
#    </yt-formatted-string>
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="alert">
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="prefilled-dialog-header">
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="simple-box">
#    <ytd-comment-simplebox-renderer class="style-scope ytd-comments-header-renderer">
#     <!--css-build:shady-->
#     <yt-img-shadow class="style-scope ytd-comment-simplebox-renderer no-transition" height="40" id="author-thumbnail" loaded="" style="background-color: transparent;" width="40">
#      <!--css-build:shady-->
#      <img alt="Default profile photo" class="style-scope yt-img-shadow" height="40" id="img" src="//s.ytimg.com/yts/img/avatar_48-vfllY0UTT.png" width="40"/>
#     </yt-img-shadow>
#     <div class="style-scope ytd-comment-simplebox-renderer" id="placeholder-area">
#      <yt-formatted-string class="style-scope ytd-comment-simplebox-renderer" id="simplebox-placeholder" role="textbox" tabindex="0">
#       Add a public comment...
#      </yt-formatted-string>
#     </div>
#     <div class="style-scope ytd-comment-simplebox-renderer" id="attachments">
#      <div class="style-scope ytd-comment-simplebox-renderer" id="image-button">
#      </div>
#     </div>
#     <div class="style-scope ytd-comment-simplebox-renderer" hidden="" id="comment-dialog">
#     </div>
#    </ytd-comment-simplebox-renderer>
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="backstage-post-dialog">
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="post-stream-filter">
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="zero-state-message">
#   </div>
#   <div class="style-scope ytd-comments-header-renderer" id="scheduling-zero-state-message">
#   </div>
#  </ytd-comments-header-renderer>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
#  <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <div class="style-scope paper-spinner-lite" id="spinnerContainer">
#    <div class="spinner-layer style-scope paper-spinner-lite">
#     <div class="circle-clipper left style-scope paper-spinner-lite">
#      <div class="circle style-scope paper-spinner-lite">
#      </div>
#     </div>
#     <div class="circle-clipper right style-scope paper-spinner-lite">
#      <div class="circle style-scope paper-spinner-lite">
#      </div>
#     </div>
#    </div>
#   </div>
#  </paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents">
#  <ytd-comment-thread-renderer class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
#    <!--css-build:shady-->
#    <div class="style-scope ytd-comment-renderer" id="body">
#     <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
#      <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCMVDN4PxXB_RFgzcZonuj4w">
#       <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40">
#        <!--css-build:shady-->
#        <img alt="Soheil Bagheri" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AATXAJyEPmrOwa_FEO3vvpIw-YiJ-gNnjhCJ3g6B_CIM=s48-c-k-c0xffffffff-no-rj-mo" width="40"/>
#       </yt-img-shadow>
#      </a>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="main">
#      <div class="style-scope ytd-comment-renderer" id="header">
#       <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
#        <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge">
#        </div>
#        <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge">
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-renderer" id="header-author">
#        <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCMVDN4PxXB_RFgzcZonuj4w" id="author-text">
#         <span class="style-scope ytd-comment-renderer">
#          Soheil Bagheri
#         </span>
#        </a>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge">
#        </span>
#        <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_="">
#         <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=UgzVftotC358uBRdOQd4AaABAg" spellcheck="false">
#          3 months ago (edited)
#         </a>
#        </yt-formatted-string>
#        <span class="style-scope ytd-comment-renderer" id="author-reputation">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#         •
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
#        </span>
#       </div>
#      </div>
#      <ytd-expander class="style-scope ytd-comment-renderer" collapsed="" id="expander" max-number-of-lines="4" should-use-number-of-lines="" style="--ytd-expander-max-lines:4;">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-expander" id="content">
#        <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
#        </yt-formatted-string>
#        <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">
#         فقط این که با کورش ۹۰ سال هم زندگی کنی پیر نمی شی و همیشه حال خوب و بمب انرژی بغلت نشسته و قطعا کورش یک کیس اوزداج عالیه
#        </yt-formatted-string>
#       </div>
#       <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="less-button style-scope ytd-comment-renderer" slot="less-button">
#         Show less
#        </span>
#       </paper-button>
#       <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="more-button style-scope ytd-comment-renderer" slot="more-button">
#         Read more
#        </span>
#       </paper-button>
#      </ytd-expander>
#      <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden="true">
#       <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=UgzVftotC358uBRdOQd4AaABAg" spellcheck="false">
#        3 months ago (edited)
#       </a>
#      </yt-formatted-string>
#      <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
#        </div>
#        <span aria-label="218 likes" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         218
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Like this comment along with 218 other people" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <span aria-label="218 likes" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         218
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Dislike this comment" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
#         <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button="" use-keyboard-focused="">
#          <a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#           <paper-button animated="" aria-disabled="false" aria-label="Reply" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0">
#            <!--css-build:shady-->
#            <yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">
#             Reply
#            </yt-formatted-string>
#           </paper-button>
#          </a>
#         </ytd-button-renderer>
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog">
#       </div>
#      </ytd-comment-action-buttons-renderer>
#      <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons">
#      </div>
#      <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" id="view-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#      <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" id="hide-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="action-menu">
#     </div>
#    </div>
#    <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog">
#    </div>
#   </ytd-comment-renderer>
#   <div class="style-scope ytd-comment-thread-renderer" id="replies">
#    <ytd-comment-replies-renderer class="style-scope ytd-comment-thread-renderer">
#     <!--css-build:shady-->
#     <div class="style-scope ytd-comment-replies-renderer" id="expander">
#      <ytd-button-renderer aria-expanded="false" button-renderer="" class="more-button style-scope ytd-comment-replies-renderer" id="more-replies" is-paper-button="" is-paper-button-with-icon="" noink="" use-keyboard-focused="">
#       <a class="yt-simple-endpoint style-scope ytd-button-renderer" tabindex="-1">
#        <paper-button animated="" aria-disabled="false" aria-label="View 32 replies" class="style-scope ytd-button-renderer" elevation="0" id="button" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope ytd-button-renderer">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M7 10l5 5 5-5z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope ytd-button-renderer" id="text">
#          View 32 replies
#         </yt-formatted-string>
#        </paper-button>
#       </a>
#      </ytd-button-renderer>
#      <ytd-button-renderer aria-expanded="true" button-renderer="" class="less-button style-scope ytd-comment-replies-renderer" hidden="" id="less-replies" is-paper-button="" is-paper-button-with-icon="" noink="" use-keyboard-focused="">
#       <a class="yt-simple-endpoint style-scope ytd-button-renderer" tabindex="-1">
#        <paper-button animated="" aria-disabled="false" aria-label="Hide 32 replies" class="style-scope ytd-button-renderer" elevation="0" id="button" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope ytd-button-renderer">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M7 14l5-5 5 5z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope ytd-button-renderer" id="text">
#          Hide 32 replies
#         </yt-formatted-string>
#        </paper-button>
#       </a>
#      </ytd-button-renderer>
#      <div class="style-scope ytd-comment-replies-renderer" hidden="" id="expander-contents">
#       <div class="style-scope ytd-comment-replies-renderer" id="loaded-replies">
#        <dom-repeat class="style-scope ytd-comment-replies-renderer">
#         <template is="dom-repeat">
#         </template>
#        </dom-repeat>
#       </div>
#       <div class="cont-button style-scope ytd-comment-replies-renderer" id="continuation">
#        <yt-next-continuation class="style-scope ytd-comment-replies-renderer">
#         <!--css-build:shady-->
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#         <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#          <!--css-build:shady-->
#          <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#           <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#            <g class="style-scope yt-icon">
#             <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#             </path>
#             <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#             </path>
#            </g>
#           </svg>
#           <!--css-build:shady-->
#          </yt-icon>
#          <yt-formatted-string class="style-scope yt-next-continuation">
#           Show more replies
#          </yt-formatted-string>
#         </paper-button>
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#        </yt-next-continuation>
#       </div>
#       <yt-next-continuation class="cont-button style-scope ytd-comment-replies-renderer" hidden="" id="fake-continuation" show-button="true" show-icon="true">
#        <!--css-build:shady-->
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#        <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#            </path>
#            <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope yt-next-continuation">
#         </yt-formatted-string>
#        </paper-button>
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#       </yt-next-continuation>
#      </div>
#     </div>
#     <div class="style-scope ytd-comment-replies-renderer" id="teaser-replies">
#     </div>
#    </ytd-comment-replies-renderer>
#   </div>
#  </ytd-comment-thread-renderer>
#  <ytd-comment-thread-renderer class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
#    <!--css-build:shady-->
#    <div class="style-scope ytd-comment-renderer" id="body">
#     <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
#      <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC8B5d-9NMIJhVz_ynstmdfA">
#       <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40">
#        <!--css-build:shady-->
#        <img alt="Maziyar mm" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AATXAJzNKn5lunramfh83RjBhXRjJ-zu9OHOAXZM0Kz_FLA=s48-c-k-c0xffffffff-no-rj-mo" width="40"/>
#       </yt-img-shadow>
#      </a>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="main">
#      <div class="style-scope ytd-comment-renderer" id="header">
#       <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
#        <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge">
#        </div>
#        <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge">
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-renderer" id="header-author">
#        <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC8B5d-9NMIJhVz_ynstmdfA" id="author-text">
#         <span class="style-scope ytd-comment-renderer">
#          Maziyar mm
#         </span>
#        </a>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge">
#        </span>
#        <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_="">
#         <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=UgyUv149W_XQ2jMNNEB4AaABAg" spellcheck="false">
#          3 months ago
#         </a>
#        </yt-formatted-string>
#        <span class="style-scope ytd-comment-renderer" id="author-reputation">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#         •
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
#        </span>
#       </div>
#      </div>
#      <ytd-expander class="style-scope ytd-comment-renderer" collapsed="" id="expander" max-number-of-lines="4" should-use-number-of-lines="" style="--ytd-expander-max-lines:4;">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-expander" id="content">
#        <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
#        </yt-formatted-string>
#        <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">
#         فقط قیافه کوروش بعد دیدن دختر مو فر فریه 😂💔
#        </yt-formatted-string>
#       </div>
#       <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="less-button style-scope ytd-comment-renderer" slot="less-button">
#         Show less
#        </span>
#       </paper-button>
#       <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="more-button style-scope ytd-comment-renderer" slot="more-button">
#         Read more
#        </span>
#       </paper-button>
#      </ytd-expander>
#      <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden="true">
#       <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=UgyUv149W_XQ2jMNNEB4AaABAg" spellcheck="false">
#        3 months ago
#       </a>
#      </yt-formatted-string>
#      <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
#        </div>
#        <span aria-label="62 likes" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         62
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Like this comment along with 62 other people" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <span aria-label="62 likes" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         62
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Dislike this comment" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
#         <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button="" use-keyboard-focused="">
#          <a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#           <paper-button animated="" aria-disabled="false" aria-label="Reply" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0">
#            <!--css-build:shady-->
#            <yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">
#             Reply
#            </yt-formatted-string>
#           </paper-button>
#          </a>
#         </ytd-button-renderer>
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog">
#       </div>
#      </ytd-comment-action-buttons-renderer>
#      <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons">
#      </div>
#      <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" id="view-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#      <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" id="hide-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="action-menu">
#     </div>
#    </div>
#    <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog">
#    </div>
#   </ytd-comment-renderer>
#   <div class="style-scope ytd-comment-thread-renderer" id="replies">
#    <ytd-comment-replies-renderer class="style-scope ytd-comment-thread-renderer">
#     <!--css-build:shady-->
#     <div class="style-scope ytd-comment-replies-renderer" id="expander">
#      <ytd-button-renderer aria-expanded="false" button-renderer="" class="more-button style-scope ytd-comment-replies-renderer" id="more-replies" is-paper-button="" is-paper-button-with-icon="" noink="" use-keyboard-focused="">
#       <a class="yt-simple-endpoint style-scope ytd-button-renderer" tabindex="-1">
#        <paper-button animated="" aria-disabled="false" aria-label="View reply" class="style-scope ytd-button-renderer" elevation="0" id="button" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope ytd-button-renderer">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M7 10l5 5 5-5z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope ytd-button-renderer" id="text">
#          View reply
#         </yt-formatted-string>
#        </paper-button>
#       </a>
#      </ytd-button-renderer>
#      <ytd-button-renderer aria-expanded="true" button-renderer="" class="less-button style-scope ytd-comment-replies-renderer" hidden="" id="less-replies" is-paper-button="" is-paper-button-with-icon="" noink="" use-keyboard-focused="">
#       <a class="yt-simple-endpoint style-scope ytd-button-renderer" tabindex="-1">
#        <paper-button animated="" aria-disabled="false" aria-label="Hide reply" class="style-scope ytd-button-renderer" elevation="0" id="button" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope ytd-button-renderer">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M7 14l5-5 5 5z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope ytd-button-renderer" id="text">
#          Hide reply
#         </yt-formatted-string>
#        </paper-button>
#       </a>
#      </ytd-button-renderer>
#      <div class="style-scope ytd-comment-replies-renderer" hidden="" id="expander-contents">
#       <div class="style-scope ytd-comment-replies-renderer" id="loaded-replies">
#        <dom-repeat class="style-scope ytd-comment-replies-renderer">
#         <template is="dom-repeat">
#         </template>
#        </dom-repeat>
#       </div>
#       <div class="cont-button style-scope ytd-comment-replies-renderer" id="continuation">
#        <yt-next-continuation class="style-scope ytd-comment-replies-renderer">
#         <!--css-build:shady-->
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#         <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#          <!--css-build:shady-->
#          <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#           <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#            <g class="style-scope yt-icon">
#             <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#             </path>
#             <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#             </path>
#            </g>
#           </svg>
#           <!--css-build:shady-->
#          </yt-icon>
#          <yt-formatted-string class="style-scope yt-next-continuation">
#           Show more replies
#          </yt-formatted-string>
#         </paper-button>
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#        </yt-next-continuation>
#       </div>
#       <yt-next-continuation class="cont-button style-scope ytd-comment-replies-renderer" hidden="" id="fake-continuation" show-button="true" show-icon="true">
#        <!--css-build:shady-->
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#        <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#            </path>
#            <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope yt-next-continuation">
#         </yt-formatted-string>
#        </paper-button>
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#       </yt-next-continuation>
#      </div>
#     </div>
#     <div class="style-scope ytd-comment-replies-renderer" id="teaser-replies">
#     </div>
#    </ytd-comment-replies-renderer>
#   </div>
#  </ytd-comment-thread-renderer>
#  <ytd-comment-thread-renderer class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
#    <!--css-build:shady-->
#    <div class="style-scope ytd-comment-renderer" id="body">
#     <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
#      <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCB-7AZb_3QFbh6As5OSU2lA">
#       <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40">
#        <!--css-build:shady-->
#        <img alt="Shervin KH" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AATXAJw-5w3ABkRu1WB27JiihzQnuUkTDAPko_CPiQ=s48-c-k-c0xffffffff-no-rj-mo" width="40"/>
#       </yt-img-shadow>
#      </a>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="main">
#      <div class="style-scope ytd-comment-renderer" id="header">
#       <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
#        <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge">
#        </div>
#        <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge">
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-renderer" id="header-author">
#        <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCB-7AZb_3QFbh6As5OSU2lA" id="author-text">
#         <span class="style-scope ytd-comment-renderer">
#          Shervin KH
#         </span>
#        </a>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge">
#        </span>
#        <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_="">
#         <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=Ugy94YjT0A5GSzg7ljF4AaABAg" spellcheck="false">
#          3 months ago (edited)
#         </a>
#        </yt-formatted-string>
#        <span class="style-scope ytd-comment-renderer" id="author-reputation">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#         •
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
#        </span>
#       </div>
#      </div>
#      <ytd-expander class="style-scope ytd-comment-renderer" collapsed="" id="expander" max-number-of-lines="4" should-use-number-of-lines="" style="--ytd-expander-max-lines:4;">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-expander" id="content">
#        <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
#        </yt-formatted-string>
#        <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">
#         <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;t=351s" spellcheck="false">
#          5:51
#         </a>
#         <span class="style-scope yt-formatted-string" dir="auto">
#          بعد فرض کن کوروش اینو باید سخت بدست بیاری😂😂
#         </span>
#         <span class="style-scope yt-formatted-string" dir="auto">
#         </span>
#         <span class="style-scope yt-formatted-string" dir="auto">
#          هی بری جلو....هی نازکنه😂
#         </span>
#         <span class="style-scope yt-formatted-string" dir="auto">
#         </span>
#         <span class="style-scope yt-formatted-string" dir="auto">
#          هی بری جلو....هی نازکنه😂
#         </span>
#        </yt-formatted-string>
#       </div>
#       <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="less-button style-scope ytd-comment-renderer" slot="less-button">
#         Show less
#        </span>
#       </paper-button>
#       <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="more-button style-scope ytd-comment-renderer" slot="more-button">
#         Read more
#        </span>
#       </paper-button>
#      </ytd-expander>
#      <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden="true">
#       <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=Ugy94YjT0A5GSzg7ljF4AaABAg" spellcheck="false">
#        3 months ago (edited)
#       </a>
#      </yt-formatted-string>
#      <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
#        </div>
#        <span aria-label="74 likes" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         74
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Like this comment along with 74 other people" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
# ...
#         </yt-formatted-string>
#        </paper-button>
#       </a>
#      </ytd-button-renderer>
#      <div class="style-scope ytd-comment-replies-renderer" hidden="" id="expander-contents">
#       <div class="style-scope ytd-comment-replies-renderer" id="loaded-replies">
#        <dom-repeat class="style-scope ytd-comment-replies-renderer">
#         <template is="dom-repeat">
#         </template>
#        </dom-repeat>
#       </div>
#       <div class="cont-button style-scope ytd-comment-replies-renderer" id="continuation">
#        <yt-next-continuation class="style-scope ytd-comment-replies-renderer">
#         <!--css-build:shady-->
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#         <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#          <!--css-build:shady-->
#          <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#           <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#            <g class="style-scope yt-icon">
#             <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#             </path>
#             <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#             </path>
#            </g>
#           </svg>
#           <!--css-build:shady-->
#          </yt-icon>
#          <yt-formatted-string class="style-scope yt-next-continuation">
#           Show more replies
#          </yt-formatted-string>
#         </paper-button>
#         <dom-if class="style-scope yt-next-continuation">
#          <template is="dom-if">
#          </template>
#         </dom-if>
#        </yt-next-continuation>
#       </div>
#       <yt-next-continuation class="cont-button style-scope ytd-comment-replies-renderer" hidden="" id="fake-continuation" show-button="true" show-icon="true">
#        <!--css-build:shady-->
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#        <paper-button animated="" aria-disabled="false" class="style-scope yt-next-continuation" elevation="0" role="button" tabindex="0">
#         <!--css-build:shady-->
#         <yt-icon class="style-scope yt-next-continuation" icon="subdirectory_arrow_right">
#          <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#           <g class="style-scope yt-icon">
#            <path class="style-scope yt-icon" d="M0 0h24v24H0V0z" fill="none">
#            </path>
#            <path class="style-scope yt-icon" d="M19 15l-6 6-1.42-1.42L15.17 16H4V4h2v10h9.17l-3.59-3.58L13 9l6 6z">
#            </path>
#           </g>
#          </svg>
#          <!--css-build:shady-->
#         </yt-icon>
#         <yt-formatted-string class="style-scope yt-next-continuation">
#         </yt-formatted-string>
#        </paper-button>
#        <dom-if class="style-scope yt-next-continuation">
#         <template is="dom-if">
#         </template>
#        </dom-if>
#       </yt-next-continuation>
#      </div>
#     </div>
#     <div class="style-scope ytd-comment-replies-renderer" id="teaser-replies">
#     </div>
#    </ytd-comment-replies-renderer>
#   </div>
#  </ytd-comment-thread-renderer>
#  <ytd-comment-thread-renderer class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
#    <!--css-build:shady-->
#    <div class="style-scope ytd-comment-renderer" id="body">
#     <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
#      <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCho14l4PqQjM68IKAbxy6OA">
#       <yt-img-shadow class="style-scope ytd-comment-renderer no-transition empty" fit="" height="40" style="background-color: transparent;" width="40">
#        <!--css-build:shady-->
#        <img alt="" class="style-scope yt-img-shadow" height="40" id="img" width="40"/>
#       </yt-img-shadow>
#      </a>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="main">
#      <div class="style-scope ytd-comment-renderer" id="header">
#       <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
#        <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge">
#        </div>
#        <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge">
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-renderer" id="header-author">
#        <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCho14l4PqQjM68IKAbxy6OA" id="author-text">
#         <span class="style-scope ytd-comment-renderer">
#          Adnan Khamar
#         </span>
#        </a>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge">
#        </span>
#        <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_="">
#         <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=Ugza091FVJYKLT3UIdd4AaABAg" spellcheck="false">
#          3 months ago
#         </a>
#        </yt-formatted-string>
#        <span class="style-scope ytd-comment-renderer" id="author-reputation">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge">
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#         •
#        </span>
#        <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
#        </span>
#       </div>
#      </div>
#      <ytd-expander class="style-scope ytd-comment-renderer" collapsed="" id="expander" max-number-of-lines="4" should-use-number-of-lines="" style="--ytd-expander-max-lines:4;">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-expander" id="content">
#        <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
#        </yt-formatted-string>
#        <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">
#         زود ب زود ویدیو بزارین. بیشترین هدفم از یوتیوب فقط دیدن ویدیو هات و ری اکشن های کوروشه✨. ، 👏
#        </yt-formatted-string>
#       </div>
#       <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="less-button style-scope ytd-comment-renderer" slot="less-button">
#         Show less
#        </span>
#       </paper-button>
#       <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0">
#        <!--css-build:shady-->
#        <span class="more-button style-scope ytd-comment-renderer" slot="more-button">
#         Read more
#        </span>
#       </paper-button>
#      </ytd-expander>
#      <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden="true">
#       <a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=K1bEFgIYuCI&amp;lc=Ugza091FVJYKLT3UIdd4AaABAg" spellcheck="false">
#        3 months ago
#       </a>
#      </yt-formatted-string>
#      <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
#       <!--css-build:shady-->
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
#        </div>
#        <span class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         0
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Like this comment along with 0 other people" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <span class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-middle">
#         0
#        </span>
#        <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button="" use-keyboard-focused="">
#         <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#          <yt-icon-button class="style-scope ytd-toggle-button-renderer style-text size-default" id="button">
#           <!--css-build:shady-->
#           <button aria-label="Dislike this comment" aria-pressed="false" class="style-scope yt-icon-button" id="button">
#            <yt-icon class="style-scope ytd-toggle-button-renderer">
#             <svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24">
#              <g class="style-scope yt-icon">
#               <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z">
#               </path>
#              </g>
#             </svg>
#             <!--css-build:shady-->
#            </yt-icon>
#           </button>
#          </yt-icon-button>
#         </a>
#        </ytd-toggle-button-renderer>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
#        </div>
#        <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
#         <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button="" use-keyboard-focused="">
#          <a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3D%252Fwatch%253Fv%253DK1bEFgIYuCI&amp;hl=en" tabindex="-1">
#           <paper-button animated="" aria-disabled="false" aria-label="Reply" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0">
#            <!--css-build:shady-->
#            <yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">
#             Reply
#            </yt-formatted-string>
#           </paper-button>
#          </a>
#         </ytd-button-renderer>
#        </div>
#       </div>
#       <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog">
#       </div>
#      </ytd-comment-action-buttons-renderer>
#      <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons">
#      </div>
#      <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" id="view-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#      <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" id="hide-threaded-replies" noink="" use-keyboard-focused="">
#      </ytd-button-renderer>
#     </div>
#     <div class="style-scope ytd-comment-renderer" id="action-menu">
#     </div>
#    </div>
#    <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog">
#    </div>
#   </ytd-comment-renderer>
#   <div class="style-scope ytd-comment-thread-renderer" hidden="" id="replies">
#   </div>
#  </ytd-comment-thread-renderer>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="continuations">
#  <yt-next-continuation class="style-scope ytd-item-section-renderer">
#   <!--css-build:shady-->
#   <paper-spinner aria-hidden="true" class="style-scope yt-next-continuation" id="spinner">
#    <!--css-build:shady-->
#    <div class="style-scope paper-spinner" id="spinnerContainer">
#     <div class="spinner-layer layer-1 style-scope paper-spinner">
#      <div class="circle-clipper left style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#      <div class="circle-clipper right style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#     </div>
#     <div class="spinner-layer layer-2 style-scope paper-spinner">
#      <div class="circle-clipper left style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#      <div class="circle-clipper right style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#     </div>
#     <div class="spinner-layer layer-3 style-scope paper-spinner">
#      <div class="circle-clipper left style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#      <div class="circle-clipper right style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#     </div>
#     <div class="spinner-layer layer-4 style-scope paper-spinner">
#      <div class="circle-clipper left style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#      <div class="circle-clipper right style-scope paper-spinner">
#       <div class="circle style-scope paper-spinner">
#       </div>
#      </div>
#     </div>
#    </div>
#   </paper-spinner>
#   <dom-if class="style-scope yt-next-continuation">
#    <template is="dom-if">
#    </template>
#   </dom-if>
#   <dom-if class="style-scope yt-next-continuation">
#    <template is="dom-if">
#    </template>
#   </dom-if>
#  </yt-next-continuation>
# </div>

# %%
# Comment Text
comments = []
for item in soup.find_all(id='content-text'):
    comments.append(item.text)
    print(item.text)
print(len(comments))
# Out:
# فقط این که با کورش ۹۰ سال هم زندگی کنی پیر نمی شی و همیشه حال خوب و بمب انرژی بغلت نشسته و قطعا کورش یک کیس اوزداج عالیه
# فقط قیافه کوروش بعد دیدن دختر مو فر فریه 😂💔
# 5:51 بعد فرض کن کوروش اینو باید سخت بدست بیاری😂😂
# هی بری جلو....هی نازکنه😂
# هی بری جلو....هی نازکنه😂
# 100% smashhhh😂😂
# koorosh is art....
# koorosh are you Ok???
# کوروش: من استانداردام بالاست
#
# تست: دختر یا پسر؟
#
# کوروش: فرقی نمیکنه
#
#
#
# 😐
# 5:51
# Ladies and gentlemen
# We GOT THEM
# FBI OPEN UP
# چقدر خوبد همیشه شادی با ویدیو های شما یکم لبمون خنده میشه با وضعیت ایران....
# معیار میا برای دوست پسرش:
# دوست داشتن بیبی یودا
# دوست داشتن هری پاتر
# دوست داشتن ارباب حلقه ها 😂😂
# آقا ناموسا جفتتون خیلی باحال و دوست داشتنی هستین اینم علت داره چون خود واقعی خودتون هستین جلو دوربین و ادا در نمیارید و این خیلی با ارزشه تو دنیای کنونی ما
# من دقت کردم که کورش به هر دو جنس گرایش داره ولی فک کنم بیشتر به پسرا ولی در آخر به میا رو آورده😂😂😂💙
# 07:26 Ariana Grande vs Gohar Kheirandish 😂😂😂
# smash= MIAAAAAA...😭😭😍😍
# 5:52   BOOOM BOOM BOOM FBI OPEN UP
# هردوتاتون بینظیرترین و فوق‌العاده‌ترین و باحال‌ترین آدمای روی زمین هستید⁦🙏🏻⁩⁦🙏🏻⁩⁦🙏🏻⁩⁦🙏🏻⁩💙💙💙💙🌹🌹🌹🌹💐💐💐💐😍😍😍😍
# 3:38 😝🦠
# بهترین ویدئوای که از میا دیدم عالی بود و به خصوص ادیت عالی عالی مرسی من این ویدیو 10 بار دیدم 😍😍😍
# عالی بودید مثل همیشه. تو دنیا دیگه مثل شماها پیدا نمیشه.
# کی مثل من گوهر خیر اندیش رو از فاصله یک متری دیده تا حالا؟😍😍
# زود ب زود ویدیو بزارین. بیشترین هدفم از یوتیوب فقط دیدن ویدیو هات و ری اکشن های کوروشه✨. ، 👏
# 20

# %%
# Author
authors = []
for jtem in soup.find_all(id="author-text"):
    authors.append(jtem.text)
    print(jtem.text)
    
print(len(authors))
# Out:
#                 Soheil Bagheri
#
#
#
#
#                 Maziyar mm
#
#
#
#
#                 Shervin KH
#
#
#
#
#                 anosha rfe
#
#
#
#
#                 ahmad abtahi
#
#
#
#
#                 Toasted Melon
#
#
#
#
#                 AMIR or PhantomBOY
#
#
#
#
#                 سینا بهرام
#
#
#
#
#                 Amirabbas
#
#
#
#
#                 Saeed Zokaei
#
#
#
#
#                 A.A !
#
#
#
#
#                 Muhammad Hussein Ammari
#
#
#
#
#                 Arran
#
#
#
#
#                 MR. googlep
#
#
#
#
#                 Nima Rezaei
#
#
#
#
#                 mazda rx-8
#
#
#
#
#                 Ali Amini
#
#
#
#
#                 Ali Primer
#
#
#
#
#                 Arman Mehrabi
#
#
#
#
#                 Adnan Khamar
#
#
# 20

# %%
# Likes
likes = []
for ktem in soup.find_all(id="vote-count-left"):
    likes.append(ktem.text)
    print(ktem.text)
print(len(likes))
# Out:
#         218
#
#
#         62
#
#
#         74
#
#
#         4
#
#
#         1
#
#
#         136
#
#
#         3
#
#
#         1
#
#
#         0
#
#
#         0
#
#
#         1
#
#
#         6
#
#
#         0
#
#
#         4
#
#
#         1
#
#
#         0
#
#
#         0
#
#
#         0
#
#
#         3
#
#
#         0
#
# 20

# %%
#Time
dates = []
for ltem in soup.find_all(class_ = "published-time-text", hidden="true"):
    dates.append(ltem.find('a').text)
    print(ltem.find('a').text)
print(len(dates))
# Out:
# 3 months ago (edited)
# 3 months ago
# 3 months ago (edited)
# 3 months ago
# 3 months ago
# 3 months ago
# 1 week ago
# 3 weeks ago
# 2 months ago
# 2 months ago
# 1 month ago
# 3 months ago (edited)
# 3 months ago
# 3 months ago
# 3 months ago
# 3 months ago
# 3 months ago
# 3 months ago
# 3 months ago
# 3 months ago
# 20

# %%
def youtube_comments_scraper(link):
    author = []
    date = []
    comment_text = []
    likes = []
    text_sentiment = []
    
    analyzer = SentimentIntensityAnalyzer()
    
    driver = webdriver.Firefox()
    driver.get(link)
    time.sleep(1.5)
    driver.execute_script("window.scrollTo(0, 1000)")
    time.sleep(0.5)
    driver.execute_script("window.scrollTo(0, 500)")
    time.sleep(1.5)
    driver.execute_script("window.scrollTo(0, 2500)")
    time.sleep(3)
    comments = driver.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer')
    soup = BeautifulSoup(comments.get_attribute('innerHTML'), 'html.parser')
    driver.close()
    for item in soup.find_all(id="author-text"):
        author.append(item.text)
    
    for jtem in soup.find_all(class_ = "published-time-text", hidden="true"):
        date.append(jtem.find('a').text)
    
    for ktem in soup.find_all(id='content-text'):
        comment_text.append(ktem.text)
        text_sentiment.append(analyzer.polarity_scores(ktem.text))
        
    for ltem in soup.find_all(id="vote-count-left"):
        likes.append(ltem.text)
        
    result = {
        'Author': author,
        'Date of Submission': date,
        'Comment': comment_text,
        'Sentiment': text_sentiment,
        'Likes': likes
    }
    return result

# %%
a = youtube_comments_scraper('https://www.youtube.com/watch?v=-dwMjQlkVT4')

# %%
print(a.keys())
print('\n\n\n')

for item in a.keys():
    print(len(a[item]))
# Out:
# dict_keys(['Author', 'Date of Submission', 'Comment', 'Sentiment', 'Likes'])
#
#
#
#
# 2
# 2
# 2
# 2
# 2

# %%
a
# Out:
# {'Author': ['\n\n                Abdullah Balobaid\n              \n',
#   '\n\n                Nawaf A\n              \n'],
#  'Date of Submission': ['3 weeks ago', '3 weeks ago'],
#  'Comment': ['Great video. As a Saudi, I’m really interested in Iran and it’s culture and hopefully I could go there in the future. \nHuge love to all Iranian brothers❤️',
#   'As a Saudi, I really hope for peace in the region so us & our Persian brothers & sisters can visit each other! As much as we look divided politically, we’re one.'],
#  'Sentiment': [{'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.9459},
#   {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.8047}],
#  'Likes': ['\n        955\n      ', '\n        525\n      ']}
