# %%
from selenium import webdriver
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def post_comments_scraper(link):
    analyzer = SentimentIntensityAnalyzer()
    driver = webdriver.Firefox()
    driver.get(link)
    time.sleep(1.5)
    post_desc = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]').find_element_by_tag_name('ul').find_element_by_tag_name('div')
    comments = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]').find_element_by_tag_name('ul').find_elements_by_tag_name('ul')
    comments_list = []
    for comment in comments:
        comment = comment.text.split("\n")
        comments_list.append({'user': comment[0],
                              'text': comment[1],
                              'stats': comment[2],
                              'scores': analyzer.polarity_scores(comment[1])})
    result = {'link': link,
              'user': post_desc.text.split("\n")[0],
              'verification': post_desc.text.split("\n")[1],
              'desc': post_desc.text.split("\n")[2],
              'score': analyzer.polarity_scores(post_desc.text.split("\n")[2]),
              'comments': comments_list}
    driver.close()
    return(result)

# %%
post_comments_scraper('https://www.instagram.com/p/BvNyVKtlfwN/')
# Out:
# {'link': 'https://www.instagram.com/p/BvNyVKtlfwN/',
#  'user': 'themelissarauch',
#  'verification': 'Verified',
#  'desc': 'Mirror, Mirror on the @bigbangtheory_cbs makeup room wall, who is shamelessly taking selfies in you during tape night?',
#  'score': {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.34},
#  'comments': [{'user': 'sanz_dl',
#    'text': '😍😍❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.7184}},
#   {'user': 'forgereaper',
#    'text': 'Perfection🙌',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.5719}},
#   {'user': 'francisco_marin_1979',
#    'text': 'TE AMO ❤️❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'raul_sg90',
#    'text': '❤️❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'starfucker57',
#    'text': 'You are so beautiful !',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.7417}},
#   {'user': 'thebobbrooks',
#    'text': 'Very cute photo Melissa. I enjoyed visiting with you after the taping a few weeks ago. Best wishes as you are completing the final few tapings. Hang in there. Bob.',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.908}},
#   {'user': 'huibei1',
#    'text': 'beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}},
#   {'user': 'richardwilhelmhohenzollern',
#    'text': 'Awesome Mrs. Rauch',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}},
#   {'user': 'shivanshprakashpal97',
#    'text': 'Some 1 is beautiful so 😗😗',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.322, 'pos': 0.678, 'compound': 0.9274}},
#   {'user': 'ibbilidstone',
#    'text': 'Beautiful girl 🌹💜',
#    'stats': '65wReply',
#    'scores': {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.8442}},
#   {'user': 'walden1968',
#    'text': 'You are so beautiful🔥🔥',
#    'stats': '64wReply',
#    'scores': {'neg': 0.401, 'neu': 0.225, 'pos': 0.374, 'compound': 0.1653}},
#   {'user': 'kirstis_not_so_secret_diary',
#    'text': 'The cutie that I’m looking at❤️',
#    'stats': '13wReply',
#    'scores': {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.3612}}]}

# %%
def post_all_comments_scraper(link):
    analyzer = SentimentIntensityAnalyzer()
    driver = webdriver.Firefox()
    driver.get(link)
    time.sleep(1.5)
    
    while len(driver.find_elements_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]/ul/li/div/button/span')) > 0:
        more_btn = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]/ul/li/div/button/span')
        more_btn.click()
        time.sleep(0.5)
            
    post_desc = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]').find_element_by_tag_name('ul').find_element_by_tag_name('div')
    comments = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/div[1]').find_element_by_tag_name('ul').find_elements_by_tag_name('ul')
    comments_list = []
    wierd = 0
    for comment in comments:
        if len(comment.text.splitlines()) >= 3:
            comment = comment.text.splitlines()
            comments_list.append({'user': comment[0],
                                  'text': comment[1],
                                  'stats': comment[2],
                                  'scores': analyzer.polarity_scores(comment[1])})
        else:
            wierd += 1
    result = {'link': link,
              'user': post_desc.text.split("\n")[0],
              'verification': post_desc.text.split("\n")[1],
              'desc': post_desc.text.split("\n")[2],
              'score': analyzer.polarity_scores(post_desc.text.split("\n")[2]),
              'likes':driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/article/div[2]/section[2]/div/div/button').text,
              'comments': comments_list}
#     driver.close()
    print('\t Number of ignored comments:', wierd)
    print('\t Number of scraped comments:', len(comments_list))
    return(result)

# %%
post_all_comments_scraper('https://www.instagram.com/p/BvNyVKtlfwN/')
# Out:
# 	 Number of ignored comments: 3
# 	 Number of scraped comments: 194
# {'link': 'https://www.instagram.com/p/BvNyVKtlfwN/',
#  'user': 'themelissarauch',
#  'verification': 'Verified',
#  'desc': 'Mirror, Mirror on the @bigbangtheory_cbs makeup room wall, who is shamelessly taking selfies in you during tape night?',
#  'score': {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.34},
#  'likes': '67,504 likes',
#  'comments': [{'user': 'moxiefoodie',
#    'text': 'bring more of that joisey accent to the last few eps of TBBT.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'maximass1138',
#    'text': 'Aww so cute ❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.5095}},
#   {'user': 'u2_hdr',
#    'text': 'my love 😍😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.9217}},
#   {'user': 'lkeats100',
#    'text': "THAT'S IT!!!!!!!!!!! I'VE LOST MY PATIENCE!!!!!!! JUST ANSWER MY GODDAMN QUESTION!!!!!!!!! WHAT GIVES YOU AND THE OTHER ACTORS AND CREATORS OF BIG BANG THEORY THE RIGHT TO ADVOCATE BULLYING AND MANIPULATE VIEWERS INTO BELIEVING THAT TERRIBLE PEOPLE ARE GOOD PEOPLE??????? AND WHY DO MILLIONS OF VIEWERS BELIEVE THAT ALL YOU'RE CHARACTERS ARE THE BEST OF THE BEST EVEN THOUGH THEY'RE NOT??????????",
#    'stats': '66wReply',
#    'scores': {'neg': 0.182, 'neu': 0.676, 'pos': 0.142, 'compound': -0.4986}},
#   {'user': 'lkeats100',
#    'text': "THAT'S IT!!!!!!!!!!! I'VE LOST MY PATIENCE!!!!!!! JUST ANSWER MY GODDAMN QUESTION!!!!!!!!! WHAT GIVES YOU AND THE OTHER ACTORS AND CREATORS OF BIG BANG THEORY THE RIGHT TO ADVOCATE BULLYING AND MANIPULATE VIEWERS INTO BELIEVING THAT TERRIBLE PEOPLE ARE GOOD PEOPLE??????? AND WHY DO MILLIONS OF VIEWERS BELIEVE THAT ALL YOU'RE CHARACTERS ARE THE BEST OF THE BEST EVEN THOUGH THEY'RE NOT??????????",
#    'stats': '66wReply',
#    'scores': {'neg': 0.182, 'neu': 0.676, 'pos': 0.142, 'compound': -0.4986}},
#   {'user': 'kessllerpoeta',
#    'text': '🌷',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'old_acc92988393838',
#    'text': 'So ur a millionaire with an iphone 7?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'sweet_inspiration_by_me',
#    'text': 'Such a cutie pie \U0001f970',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.38, 'pos': 0.62, 'compound': 0.8689}},
#   {'user': 'altooctanage',
#    'text': 'Eres la más linda del mundo i am your fan from peru',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}},
#   {'user': 'm.usman_ak',
#    'text': 'I love her hilariousness. ❤️ M. Rauch',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}},
#   {'user': 'dev_joshi_9',
#    'text': 'I dont want to be that guy but, its actually "magic mirror" instead of "mirror mirror" some ppl think it\'s a Mandela effect.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.048, 'neu': 0.952, 'pos': 0.0, 'compound': -0.0286}},
#   {'user': 'ifernlopezquezon',
#    'text': '@jhangs22',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'sanz_dl',
#    'text': '😍😍❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.7184}},
#   {'user': 'forgereaper',
#    'text': 'Perfection🙌',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.5719}},
#   {'user': 'francisco_marin_1979',
#    'text': 'TE AMO ❤️❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'raul_sg90',
#    'text': '❤️❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'starfucker57',
#    'text': 'You are so beautiful !',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.7417}},
#   {'user': 'thebobbrooks',
#    'text': 'Very cute photo Melissa. I enjoyed visiting with you after the taping a few weeks ago. Best wishes as you are completing the final few tapings. Hang in there. Bob.',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.908}},
#   {'user': 'huibei1',
#    'text': 'beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}},
#   {'user': 'richardwilhelmhohenzollern',
#    'text': 'Awesome Mrs. Rauch',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}},
#   {'user': 'shivanshprakashpal97',
#    'text': 'Some 1 is beautiful so 😗😗',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.322, 'pos': 0.678, 'compound': 0.9274}},
#   {'user': 'ibbilidstone',
#    'text': 'Beautiful girl 🌹💜',
#    'stats': '65wReply',
#    'scores': {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.8442}},
#   {'user': 'walden1968',
#    'text': 'You are so beautiful🔥🔥',
#    'stats': '64wReply',
#    'scores': {'neg': 0.401, 'neu': 0.225, 'pos': 0.374, 'compound': 0.1653}},
#   {'user': 'kirstis_not_so_secret_diary',
#    'text': 'The cutie that I’m looking at❤️',
#    'stats': '13wReply',
#    'scores': {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.3612}},
#   {'user': 'eyckheppner',
#    'text': "I can see you doing talk show's after big bang",
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': '_raphanevess',
#    'text': 'MARAVILHOSAAAA 💞',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.317, 'pos': 0.683, 'compound': 0.6486}},
#   {'user': 'idlemovement831',
#    'text': '😍☝️',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.4588}},
#   {'user': 'randallfranz',
#    'text': 'Hahaha',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5574}},
#   {'user': 'mowroze',
#    'text': 'We will miss you so much ...😭',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.37, 'neu': 0.63, 'pos': 0.0, 'compound': -0.5719}},
#   {'user': 'felitbbt',
#    'text': 'Que hermosa :-)',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.3182}},
#   {'user': 'marklee9426',
#    'text': "Hopefully you will get your own show! You're incredible",
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.4574}},
#   {'user': 'bill13204',
#    'text': '😍',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}},
#   {'user': 'amy_davidson',
#    'text': 'Verified',
#    'stats': 'Cutie💓',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'gamemom1953',
#    'text': 'Beautiful!!!🌷💕',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.181, 'pos': 0.819, 'compound': 0.8772}},
#   {'user': 'minimom1969',
#    'text': 'Melissa will you be glad to not have to do Bernadette’s voice anymore? I was shocked when I saw you in The Bronze and you didn’t actually speak that way! Lol! Love you!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.055, 'neu': 0.688, 'pos': 0.258, 'compound': 0.8617}},
#   {'user': 'paulocesar908579',
#    'text': 'A única neurocientista que amo',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'mama_linddda',
#    'text': 'Gonna miss Bernadette so much!',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.321, 'neu': 0.679, 'pos': 0.0, 'compound': -0.2244}},
#   {'user': 'ify8753',
#    'text': '👌🔝',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.103, 'pos': 0.897, 'compound': 0.8256}},
#   {'user': 'beav222',
#    'text': 'Hi !!!!!!!!',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'cvetlyahook_ogonehek',
#    'text': 'Beautiful 💖',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.8834}},
#   {'user': 'lauravalarie',
#    'text': "❣❄❣ Every action has a reaction. Think before doing anything. Cause once its done it can't be undone or unsaid. ❣❄❣",
#    'stats': '❣❄❣ Wishing you an amazing, productive, stress free and blessed Wednesday. ❣❄❣',
#    'scores': {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.9571}},
#   {'user': 'luismoreno3410',
#    'text': '😍',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}},
#   {'user': 'johsamur',
#    'text': '😍😍😍',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.8402}},
#   {'user': 'kimmers63',
#    'text': 'I am going to miss all of you @thebigbangtheory__ so much👏👏👏💖',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.067, 'neu': 0.667, 'pos': 0.267, 'compound': 0.7003}},
#   {'user': 'barb_e_feebs1984',
#    'text': 'Beautiful',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}},
#   {'user': 'jessehatcher724_8647076538',
#    'text': 'Hey beautiful',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.204, 'pos': 0.796, 'compound': 0.5994}},
#   {'user': 'isabel_x._mendoza83',
#    'text': 'very beautiful',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.193, 'pos': 0.807, 'compound': 0.6361}},
#   {'user': 's.razi.siadat',
#    'text': 'Happy nowruz dear 😍😙',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.304, 'pos': 0.696, 'compound': 0.9432}},
#   {'user': 'barreradjd',
#    'text': '😍😍😘😘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.891}},
#   {'user': 'ldt_bell_canada',
#    'text': "@mcal1221 it is in front of a live audience, they have mua's for the cast.",
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'aaronl.long',
#    'text': 'Beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}},
#   {'user': 'mackarena_mad',
#    'text': 'bella 💕',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.317, 'pos': 0.683, 'compound': 0.6486}},
#   {'user': 'andreiacosta01977',
#    'text': '😍❤️😍Maravilhosa❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7184}},
#   {'user': 'brosprouts',
#    'text': '❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'philipwebre',
#    'text': '@themelissarauch sweet Melissa beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.225, 'pos': 0.775, 'compound': 0.7845}},
#   {'user': 'dan.pine.7',
#    'text': 'Met you 3 years ago at an after-taping meet-and- greet. You didn’t know me but you were SO kind and friendly. I’ll never forget it. I will miss your amazing show',
#    'stats': '66wReply',
#    'scores': {'neg': 0.039, 'neu': 0.512, 'pos': 0.449, 'compound': 0.9721}},
#   {'user': 'sunlessbrute82',
#    'text': 'Girl finger shown from bottom of sink to faucet.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'pinucciooo52',
#    'text': 'Ti amo melissa',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'morrisroxa',
#    'text': "You are so amazing and Very beautiful. I so wish I could meet you. My 14 year old daughter is also a fan she loves Harley Quinn and when she found out you her voice for a Batman cartoon she was an even bigger fan. Bernadette is one of my favorite characters because she's not afraid to tell people how she feels. I'm so sad to see the final season but I know you will go on to do bigger things.",
#    'stats': '66wReply',
#    'scores': {'neg': 0.028, 'neu': 0.805, 'pos': 0.167, 'compound': 0.8651}},
#   {'user': 'anaro461',
#    'text': 'Hermosa!',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'ahkess',
#    'text': 'Did the mirror answer? 😂',
#    'stats': '66wReply',
#    'scores': {'neg': 0.15, 'neu': 0.551, 'pos': 0.299, 'compound': 0.4404}},
#   {'user': 'backcountryjedi',
#    'text': 'Such a beauty',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.5859}},
#   {'user': 'les.cherry',
#    'text': 'Looking amazing!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6239}},
#   {'user': 'gossoshooter',
#    'text': '💓💓💓大好き💓💓💓',
#    'stats': '66wReply',
#    'scores': {'neg': 0.361, 'neu': 0.024, 'pos': 0.614, 'compound': 0.926}},
#   {'user': 'socalsesh',
#    'text': 'had an awesome time last night, 👏👏👏👏thank you to the whole cast & crew',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}},
#   {'user': 'm01khy',
#    'text': 'You are gorgeous!😎🐒',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.451, 'pos': 0.549, 'compound': 0.807}},
#   {'user': 'nici_bei',
#    'text': '♥️♥️♥️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.9274}},
#   {'user': 'shakeyjr22',
#    'text': '@themelissarauch 💓What is your next project ? Staring , Producing ?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.234, 'neu': 0.766, 'pos': 0.0, 'compound': -0.5204}},
#   {'user': 'm_cale7785',
#    'text': 'How is The Big Bang Theory filmed? Is it on a sound stage where there are people watching? Do you apply your own makeup or are there make up artists?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 't_dog11500',
#    'text': 'You and @kunalkarmanayyar lol',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}},
#   {'user': 'thebelvedere',
#    'text': 'Looks like the leading lady in a Big Bang spin off ?? The Walowitz’s ?? @themelissarauch',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.5362}},
#   {'user': 'katferxita',
#    'text': '😍😍😍😍 beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.43, 'pos': 0.57, 'compound': 0.9423}},
#   {'user': 'coffeeaddictedmusicjunkie',
#    'text': '@annagold',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'sophiadesousa_',
#    'text': 'Beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}},
#   {'user': 'seaboy22',
#    'text': 'Mirror: the stunning meli babe!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4389}},
#   {'user': 'sarrum7696',
#    'text': 'I totally think a spin-off without Sheldon, Leonard and Penny would be great!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.6588}},
#   {'user': 'abe.652',
#    'text': '🔥😘🔥',
#    'stats': '66wReply',
#    'scores': {'neg': 0.453, 'neu': 0.283, 'pos': 0.264, 'compound': -0.25}},
#   {'user': 'dchapgrandpa_',
#    'text': 'Wow ! ... I mean , very nice 😉',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.527, 'pos': 0.473, 'compound': 0.8012}},
#   {'user': 'jamzip',
#    'text': '🔥🔥',
#    'stats': '66wReply',
#    'scores': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859}},
#   {'user': 'gon_armando',
#    'text': '💙',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}},
#   {'user': 'shinyshannon',
#    'text': "I love that you're just like me and leave your car keys on your desk. ;)",
#    'stats': '66wReply',
#    'scores': {'neg': 0.055, 'neu': 0.55, 'pos': 0.394, 'compound': 0.8126}},
#   {'user': 'jjcatrone',
#    'text': 'Hottie',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'jacksully88',
#    'text': '😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}},
#   {'user': 'yellowismine123',
#    'text': 'So a beautiful woman 😜❤️',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.6344}},
#   {'user': 'mullygirl1',
#    'text': 'I hate that they changed the way you dress on bbt. It was so cute',
#    'stats': '66wReply',
#    'scores': {'neg': 0.18, 'neu': 0.632, 'pos': 0.188, 'compound': 0.0429}},
#   {'user': 'jeanniebabeanie',
#    'text': 'Love her!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.182, 'pos': 0.818, 'compound': 0.6696}},
#   {'user': 'pezlisa',
#    'text': 'Lovely',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5859}},
#   {'user': 'jamielang123',
#    'text': 'Try a bobcut after BB 💇\u200d♀️💇\u200d♀️😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.4588}},
#   {'user': 'pedroregislima',
#    'text': 'Ola, gostaria de dar um ideia, se possível no último episodio da série "The Big Teori", poderiam fazer baseado em Sherlock Holmes & Watson no papel Sheldon e Leonard. Pega a visão Pedro Regis Lima',
#    'stats': '66wReply',
#    'scores': {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.5267}},
#   {'user': 'jazarmando',
#    'text': 'Your so beautiful and love them eyes',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.366, 'pos': 0.634, 'compound': 0.8643}},
#   {'user': 'pba02',
#    'text': 'So beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.193, 'pos': 0.807, 'compound': 0.6361}},
#   {'user': 'sara.aranguren',
#    'text': '😘😘 beautiful!!!! 😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.397, 'pos': 0.603, 'compound': 0.9283}},
#   {'user': 'harojr.jesse',
#    'text': 'Oh.. Melissa 💗🐎',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.7096}},
#   {'user': 'marceljo.francineau',
#    'text': '🔥🔥🔥',
#    'stats': '66wReply',
#    'scores': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.7351}},
#   {'user': 'fabio.mufarrej',
#    'text': '♥♥♥',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.9274}},
#   {'user': 'neeleybob',
#    'text': 'Lol. Have a great day.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.7845}},
#   {'user': 'lkeats100',
#    'text': "THAT'S IT!!!!!!!!!!! I'VE LOST MY PATIENCE!!!!!!! JUST ANSWER MY GODDAMN QUESTION!!!!!!!!! WHAT GIVES YOU AND THE OTHER ACTORS AND CREATORS OF BIG BANG THEORY THE RIGHT TO ADVOCATE BULLYING AND MANIPULATE VIEWERS INTO BELIEVING THAT TERRIBLE PEOPLE ARE GOOD PEOPLE??????? AND WHY DO MILLIONS OF VIEWERS BELIEVE THAT ALL YOU'RE CHARACTERS ARE THE BEST OF THE BEST EVEN THOUGH THEY'RE NOT??????????",
#    'stats': '66wReply',
#    'scores': {'neg': 0.182, 'neu': 0.676, 'pos': 0.142, 'compound': -0.4986}},
#   {'user': 'lkeats100',
#    'text': "THAT'S IT!!!!!!!!!!! I'VE LOST MY PATIENCE!!!!!!! JUST ANSWER MY GODDAMN QUESTION!!!!!!!!! WHAT GIVES YOU AND THE OTHER ACTORS AND CREATORS OF BIG BANG THEORY THE RIGHT TO ADVOCATE BULLYING AND MANIPULATE VIEWERS INTO BELIEVING THAT TERRIBLE PEOPLE ARE GOOD PEOPLE??????? AND WHY DO MILLIONS OF VIEWERS BELIEVE THAT ALL YOU'RE CHARACTERS ARE THE BEST OF THE BEST EVEN THOUGH THEY'RE NOT??????????",
#    'stats': '66wReply',
#    'scores': {'neg': 0.182, 'neu': 0.676, 'pos': 0.142, 'compound': -0.4986}},
#   {'user': 'wannabechef07',
#    'text': '5',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'roberiofycial',
#    'text': 'Bernie ❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'valiryan',
#    'text': 'Sooo cuuute!! 😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.582, 'pos': 0.418, 'compound': 0.555}},
#   {'user': 'luyz_thyago_alves',
#    'text': '💐❤️💕',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.482, 'pos': 0.518, 'compound': 0.6486}},
#   {'user': 'michajohn79',
#    'text': '😍😍😍😍✌✌',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.432, 'pos': 0.568, 'compound': 0.9545}},
#   {'user': 'harold.winkler',
#    'text': '😊❤️🙏',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.538, 'pos': 0.462, 'compound': 0.7184}},
#   {'user': 'kjblack3126',
#    'text': 'Well, when you are glammed up by the pros, why not? 😁',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.6249}},
#   {'user': 'pat67aug',
#    'text': '🔥🔥🔥🔥🔥💘💘💘💘💘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.279, 'neu': 0.233, 'pos': 0.488, 'compound': 0.9186}},
#   {'user': 'whelms01',
#    'text': 'Looking good',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}},
#   {'user': 'victoria__quan',
#    'text': 'ha,an angel❤',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6369}},
#   {'user': 'redbeard2000',
#    'text': '👌 😍 😘 ❤️ 👌 More selfies the better I say x',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.397, 'pos': 0.603, 'compound': 0.9649}},
#   {'user': 'ordjon12',
#    'text': '@hashika_v',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'sonofsairashk',
#    'text': 'I can hear this picture shouting at Howard 😂😂😂😂😂😂😂',
#    'stats': '66wReply',
#    'scores': {'neg': 0.193, 'neu': 0.421, 'pos': 0.386, 'compound': 0.9601}},
#   {'user': 'syjacobus',
#    'text': 'Hubby @brandtjacobus and I came to see the taping of the show tonight! We had a fun time. Still sad that the show will end, but thankful for all the years of nonstop laughs! Congratulations to all of you!! @themelissarauch ✨✨✨✨🎉🎉🎉❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.023, 'neu': 0.52, 'pos': 0.457, 'compound': 0.9908}},
#   {'user': 'amiblu4200',
#    'text': 'Hey Pretty🙋🏻',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.7506}},
#   {'user': 'madhatter094',
#    'text': '❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'christopher.mke',
#    'text': 'Always...you 😋',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'magno424',
#    'text': '❤️❤️❤️🔥🔥',
#    'stats': '66wReply',
#    'scores': {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.5859}},
#   {'user': 'kowal1976',
#    'text': '😘😍🤗❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.511, 'pos': 0.489, 'compound': 0.8225}},
#   {'user': 'mrsdeeva22',
#    'text': '🤣🤣🤣',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.8625}},
#   {'user': 'fredoaurel',
#    'text': 'Très belle 😉',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'spymate77',
#    'text': 'I like your face ^_^',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}},
#   {'user': 'zolrakk',
#    'text': '😍😍😍 beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.9169}},
#   {'user': 'rafanfy',
#    'text': '❤',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}},
#   {'user': 'firewolf316',
#    'text': 'Marry me lol I’ll be a great side husband like I’m not even around.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.8555}},
#   {'user': 'charlyzara2001',
#    'text': 'I love u!!! 🙏🙏😍😍💞💞',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.416, 'pos': 0.584, 'compound': 0.9669}},
#   {'user': 'calmgodsworld',
#    'text': 'Cute',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}},
#   {'user': 'waltonmm31',
#    'text': 'Omg looks just like Bernadette! Is that really you?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4199}},
#   {'user': 'alex.kersten',
#    'text': 'you are SOO pretty 💘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.403, 'pos': 0.597, 'compound': 0.8126}},
#   {'user': 'djrobin85',
#    'text': '☺️👏',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}},
#   {'user': 'senthilk141',
#    'text': 'Nice',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}},
#   {'user': 'dome.grn',
#    'text': 'Beautiful 🌠💕',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.268, 'pos': 0.732, 'compound': 0.8481}},
#   {'user': 'bengies5',
#    'text': '"My queen, you\'re the beautiful one here..."',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.5994}},
#   {'user': 'fredwader',
#    'text': '🇧🇷Linda🇧🇷',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'matthew.tucker.7359',
#    'text': 'I love watching and the other big bang theory stars i think you all are awesome',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'compound': 0.8519}},
#   {'user': 'correriacarol',
#    'text': 'Bernnie minha deusaaa',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'meader.mark',
#    'text': 'Will So Miss You, Hope You have something lined up just as Good!!❤️❤️',
#    'stats': '66w1 likeReply',
#    'scores': {'neg': 0.084, 'neu': 0.621, 'pos': 0.295, 'compound': 0.6961}},
#   {'user': 'islandgirl7765',
#    'text': 'Beautiful ❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.5994}},
#   {'user': 'apollo21lmp',
#    'text': "someone needs to invent a smart phone that looks like a hand so when you take a selfie it just looks like you're waving at the camera.",
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.872}},
#   {'user': 'litts1981',
#    'text': 'Is it @themelissarauch ? Did i get it right?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'klines_customs',
#    'text': '🔥🔥🔥🔥🔥❤️❤️❤️❤️❤️',
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.545, 'neu': 0.455, 'pos': 0.0, 'compound': -0.875}},
#   {'user': 'yernye',
#    'text': 'Looking good n pretty',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.247, 'pos': 0.753, 'compound': 0.7269}},
#   {'user': 'lisssandrooo',
#    'text': '😍😍😍😍💘💘💘💘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.41, 'pos': 0.59, 'compound': 0.9831}},
#   {'user': 'mahdsbt',
#    'text': '😍😍😍😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.9325}},
#   {'user': 'matiasc8725',
#    'text': 'Hermosa💘😍🌹🌹',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.802}},
#   {'user': 'loroxburgh',
#    'text': 'Verified',
#    'stats': 'Love that beautiful face and soul ❤️',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'evellynmiiranda',
#    'text': '❤️',
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'leaandro_rj',
#    'text': 'Quer namorar cmg? 😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.4588}},
#   {'user': 'andcvlls',
#    'text': '❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️😍😍😍😍😍😍😍😍😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.9818}},
#   {'user': 'franymol.11',
#    'text': '😍😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.8402}},
#   {'user': 'thomasallen3271',
#    'text': '❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'rod_69',
#    'text': '😘😘😘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.8126}},
#   {'user': 'leosaturnsouza',
#    'text': 'Hermosa',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'juanjo_flores_1203',
#    'text': 'A Love Melissa',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}},
#   {'user': 'rgbcn',
#    'text': '😍😍😍😍',
#    'stats': '66w3 likesReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.9001}},
#   {'user': 'silvanabazanc',
#    'text': 'Amiga @jossymelissa.gt es igualita a tu amiga de España.',
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'cdgsuf',
#    'text': 'Bernadette always looks perfect. Be fun to see her all scraggly now and then!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.807}},
#   {'user': '_____c_a_i_l_l_o_u_____',
#    'text': 'When the next episode',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'scottsmith958',
#    'text': 'Hello how are you doing',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'mannoo_vycttor',
#    'text': '❤❤❤',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.9274}},
#   {'user': 'mscynmet',
#    'text': 'Gorgeous angle. My glamour selfies look like @rickygervais bathtub selfies.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.414, 'pos': 0.586, 'compound': 0.872}},
#   {'user': 'k10photography',
#    'text': 'Silly question: why did Bernie make the switch from dresses to pants?',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.0258}},
#   {'user': 'senseialan',
#    'text': 'Do you and the gang still #standwithjussie? Idiots.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'diana_rich1717',
#    'text': 'Beautiful ❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.5994}},
#   {'user': 'iammaxvaliente',
#    'text': 'You are 😊',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.7184}},
#   {'user': 'el_lalo_shakur',
#    'text': 'So beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.193, 'pos': 0.807, 'compound': 0.6361}},
#   {'user': 'fgs.oficial',
#    'text': '@themelissarauch cutest actress ever! 😍😘',
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.8718}},
#   {'user': 'meeeegan2',
#    'text': 'We were #7 and 8 in the standby line today and didn’t make it in 😞 So bummed to miss out on seeing you all!! Can’t imagine how you all must be feeling as the last episodes get filmed.',
#    'stats': '66wReply',
#    'scores': {'neg': 0.126, 'neu': 0.84, 'pos': 0.034, 'compound': -0.6184}},
#   {'user': 'eyonblood',
#    'text': '#1 stunner',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'j.e.camachotorres',
#    'text': '😍😍😍😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.9325}},
#   {'user': 'leonidasxo',
#    'text': '🙌🏼',
#    'stats': '66w2 likesReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'fangbricker',
#    'text': '❤️❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'pianista560',
#    'text': 'You look so nice !!!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.6697}},
#   {'user': 'dedinseyed',
#    'text': 'Adorable!!!!!! 😍😍 @themelissarauch',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.403, 'pos': 0.597, 'compound': 0.8852}},
#   {'user': 'odelay_slowdecay',
#    'text': 'Only one of the most beautiful women alive',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.46, 'pos': 0.54, 'compound': 0.7939}},
#   {'user': 'dizzledang',
#    'text': '@themelissarauch we love u!',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.6696}},
#   {'user': 'diego.diamond',
#    'text': '😍😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.7184}},
#   {'user': 'loverbyswift',
#    'text': 'u are so bernie',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'prasad_shettys',
#    'text': '😮 Woooooooowi',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#   {'user': 'brianweber81',
#    'text': '🤘🤘👍👍😍😍🔥🔥',
#    'stats': '66wReply',
#    'scores': {'neg': 0.167, 'neu': 0.625, 'pos': 0.208, 'compound': 0.296}},
#   {'user': 'stinesb23',
#    'text': 'Why, THE FAIREST ONE of all of course. You know you’re GORGEOUS!😍You don’t have to fish for compliments in the mirror.',
#    'stats': '✌️❤️😁 and 🌹🌹🌹🌹🌹🌹!',
#    'scores': {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'compound': 0.8939}},
#   {'user': 'thefarihajawed',
#    'text': 'You are beautiful❤️...... I love you😘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.452, 'pos': 0.548, 'compound': 0.8979}},
#   {'user': 'aaronadame9',
#    'text': '❤❤',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.8555}},
#   {'user': 'anbar_villek',
#    'text': 'You are the best 🌹',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}},
#   {'user': 'emma.radford.7587',
#    'text': '@themelissarauch that’s a shame we missed it. We didn’t manage to get in today after a long day wait. 😥 would have love to see you all. ❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.136, 'neu': 0.644, 'pos': 0.22, 'compound': 0.7579}},
#   {'user': 'beltics17',
#    'text': 'You are the best! My favorite from TBBT ♥',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.374, 'pos': 0.626, 'compound': 0.9134}},
#   {'user': 'almacuqr_',
#    'text': 'Beautiful.💓',
#    'stats': '66wReply',
#    'scores': {'neg': 0.27, 'neu': 0.0, 'pos': 0.73, 'compound': 0.7269}},
#   {'user': 'abramfer',
#    'text': "Love'u♥️",
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}},
#   {'user': 'occdevil',
#    'text': 'i like you so many years and you are sooooo beautiful',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.7506}},
#   {'user': 'lks16',
#    'text': 'Love is in the air 😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.493, 'pos': 0.507, 'compound': 0.802}},
#   {'user': 'geraldlp30',
#    'text': 'So beautiful😍😍😍😘😘😘',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.9677}},
#   {'user': 'leu_fda',
#    'text': 'Linda 🇧🇷🙌❤',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}},
#   {'user': 'francesca.stellino',
#    'text': 'wow a queen',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.5859}},
#   {'user': 'enp81',
#    'text': '😍',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}},
#   {'user': 'beetlebugs',
#    'text': 'Love this❤️❤️❤️',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}},
#   {'user': 'beetlebugs',
#    'text': 'Love from the z Catman and my Siamese brats',
#    'stats': '66wReply',
#    'scores': {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}}]}
